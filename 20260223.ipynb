# %% [markdown]
# <a href="https://colab.research.google.com/github/clarencekks/nkr_2026/blob/main/20260223.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. jupyter notebook的文字是使用markdown語法
# 2. 完整python檔案 .py結尾, jupyter notebook這個python工具產生的是 .ipynb結尾
# 3. colab基本就是一個線上版本的jupyter notebook
# 4. 文字還支援一種特殊語法: latex math
#
# $ Area = \frac{1}{2} \pi {R_1}^2 $

# %% [markdown]
# ```
# 完全平方日練習
#
# 20241001(4499**2)開始, 往後多數10個完全平方日
#
# 想法:
# 1. 2024/10/01(可否開根號)
#    2024/10/02(可否開根號)
#    2024/10/03...
#
# 2. 4499*4499(是否一個日期)
#    4500*4500(是否一個日期)
#    4501*4501...
#
# 所需時間!
# 你到下一個完全平方日要數幾次
# (2072/07/04 = 4552 * 4552)
# 想法1. 48(年) * 365 = 17520次
# 想法2. 4552 - 4499 = 103個
#
# 理論上就差了100倍的時間差:
# 想法2會是你的選擇
#
# 想法2實作
# 一個一個數字數過去, 平方, 確認是否為一個日期
#
# 1. 年: >=1
# 2. 月: 12~1
# 3. 日: 每個月不一樣/如果是二月要確認是否為閏年(29天)
#
# ```

# %%
# if-else的語法
bmi = 17
if bmi > 25:
    print("過重")
elif bmi > 18:
    print("正常")
else:
    print("過輕")
# Out:
# 過輕

# %% [markdown]
# ![88051068_2788000684622679_274394280741568512_n.jpg](data:image/jpeg;base64,...)

# %%
# 3: X
# 4: O
# 100: X
# 400: O
year = 2000

if year % 4 == 0:
    if year % 100 == 0:
        if year % 400 == 0:
            print("閏年")
        else:
            print("平年")
    else:
        print("閏年")
else:
    print("平年")
# Out:
# 閏年

# %%
year = 2000
if year % 400 == 0:
    print("閏年")
elif year % 100 == 0:
    print("平年")
elif year % 4 == 0:
    print("閏年")
else:
    print("平年")
# Out:
# 閏年

# %%
# 定義功能的語法
def add(x, y):
    z = x + y
    return z

print(add(3, 5))
print(add(4, 6))
# Out:
# 8
# 10

# %%
# 快捷鍵: tab shift+tab
# 布林型態: True False
def is_leap_year(year):
    if year % 400 == 0:
        return True
    elif year % 100 == 0:
        return False
    elif year % 4 == 0:
        return True
    else:
        return False

print(is_leap_year(2000))
print(is_leap_year(1999))
# Out:
# True
# False
