# %% [markdown]
# <a href="https://colab.research.google.com/github/clarencekks/nkr_2026/blob/main/20260223_FirstClass.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. jupyter markdown
# 2. teest
# 3. latex math
#
# $ Area = \frac{1}{2}\pi {R_1}^2
# $

# %%
a = 3
print(a)
# Out:
# 3

# %%
print(a+2)
# Out:
# 5
